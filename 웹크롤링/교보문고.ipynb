# %%
import requests
from bs4 import BeautifulSoup
import re

url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page=1&per=20&ymw=&period=001&saleCmdtClstCode=&dsplDvsnCode=000&dsplTrgtDvsnCode=001&saleCmdtDsplDvsnCode="
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')
#print(soup)
li =bs_obj.find("li",{"class":"prod_item"})

lis = li.findAll("li")

for lii in lis:
    a_tag =lii.find("a")
    print(a_tag)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\gusdk\OneDrive\바탕 화면\금오공대 1-2\ai프로그래밍\ai-programming\웹크롤링\교보문고.ipynb 셀 1 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/gusdk/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EA%B8%88%EC%98%A4%EA%B3%B5%EB%8C%80%201-2/ai%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/ai-programming/%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81/%EA%B5%90%EB%B3%B4%EB%AC%B8%EA%B3%A0.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> #print(soup)
#      <a href='vscode-notebook-cell:/c%3A/Users/gusdk/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EA%B8%88%EC%98%A4%EA%B3%B5%EB%8C%80%201-2/ai%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/ai-programming/%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81/%EA%B5%90%EB%B3%B4%EB%AC%B8%EA%B3%A0.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> li =bs_obj.find("li",{"class":"prod_item"})
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re

url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page=1&per=20&ymw=&period=001&saleCmdtClstCode=&dsplDvsnCode=000&dsplTrgtDvsnCode=001&saleCmdtDsplDvsnCode="
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')

# Find all li elements with class "prod_item"
li_items = soup.find_all("li", {"class": "prod_item"})

for li in li_items:
    a_tag = li.find("a")
    print(a_tag)

# %%
#a태그만 뽑아오기

import requests
from bs4 import BeautifulSoup
import re

url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page=1&per=20&ymw=&period=001&saleCmdtClstCode=&dsplDvsnCode=000&dsplTrgtDvsnCode=001&saleCmdtDsplDvsnCode="
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')

# Find all 'a' tags in the HTML content
a_tags = soup.find_all('a')

# Print the 'a' tags
for a_tag in a_tags:
    print(a_tag)
# Out:
# <a href="#contents">본문 바로가기</a>
# <a class="service_mall_link link_ebook" href="https://ebook.kyobobook.co.kr/" id="mallLinkEbook" onclick="ga360.GA_Event('click_공통_PC', '헤더', '', 'eBook', '');">
# <use href="/assets/images/common/img_service_mall_tab.svg#pathTab"></use> <!-- 수정 211207 fill color 전페이지 공통 수정 --> </a>
# <a class="service_mall_link link_sam" href="https://sam.kyobobook.co.kr/dig/pnd/showcase?pageNo=12" id="mallLinkSAM" onclick="ga360.GA_Event('click_공통_PC', '헤더', '', 'sam', '');">
# <use href="/assets/images/common/img_service_mall_tab.svg#pathTab"></use> </a>
# <a class="service_mall_link link_hot_tracks" href="https://hottracks.kyobobook.co.kr" id="mallLinkHotTracks" onclick="ga360.GA_Event('click_공통_PC', '헤더', '', '핫트랙스', '');">
# <use href="/assets/images/common/img_service_mall_tab.svg#pathTab"></use> </a>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page=1&per=20&ymw=&period=001&saleCmdtClstCode=&dsplDvsnCode=000&dsplTrgtDvsnCode=001&saleCmdtDsplDvsnCode="
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')

# Find all parent elements containing both "prod_name" and "prod_info"
parent_elements = soup.find_all('div', class_='prod_info')

# Extract and print the text from each parent element
for parent_element in parent_elements:
    prod_name = parent_element.find_previous('span', class_='prod_name')
    if prod_name:
        following_text = parent_element.get_text(strip=True, separator=' ')
        print(following_text)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page=1&per=20&ymw=&period=001&saleCmdtClstCode=&dsplDvsnCode=000&dsplTrgtDvsnCode=001&saleCmdtDsplDvsnCode="
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')

boxes = div.find_all("li", {class}:"prod_item")

def get_book_info(prod_item):
    ptag = prod_item.find("div", {"class": "peod_area horizontal"})
    spans = ptag.find_all("span")

# %%
import requests
from bs4 import BeautifulSoup

url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page=1&per=20&ymw=&period=001&saleCmdtClstCode=&dsplDvsnCode=000&dsplTrgtDvsnCode=001&saleCmdtDsplDvsnCode="
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')

# Find all <li> elements
li_elements = soup.find_all('li')

# Print the <li> elements
for li_element in li_elements:
    print(li_element)
# Out:
# <li class="service_mall_item">
# <svg viewbox="0 0 565 33" xmlns="http://www.w3.org/2000/svg"> <!--<g transform="translate(0 0)">
#         <a id="mallLinkEbook" href="#" class="service_mall_link link_kyobo">
#             <use href="/assets/common/images/img_service_mall_tab.svg#pathTab" />
#         </a>
#         <text x="64" y="15" dy=".5em" aria-labelledby="mallLinkEbook">교보문고</text>
#     </g>--> <g transform="translate(0 0)">
# <a class="service_mall_link link_ebook" href="https://ebook.kyobobook.co.kr/" id="mallLinkEbook" onclick="ga360.GA_Event('click_공통_PC', '헤더', '', 'eBook', '');">
# <use href="/assets/images/common/img_service_mall_tab.svg#pathTab"></use> <!-- 수정 211207 fill color 전페이지 공통 수정 --> </a>
# <text aria-labelledby="mallLinkEbook" dy=".5em" font-size="14px" x="64" y="15">
#          eBook
#         </text>
# </g> <g transform="translate(87 0)">
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page=1&per=20&ymw=&period=001&saleCmdtClstCode=&dsplDvsnCode=000&dsplTrgtDvsnCode=001&saleCmdtDsplDvsnCode="
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')

# Find all <li> elements with class "depth_item"
li_elements_with_class = soup.find_all('li', class_='depth_item')

# Print the <li> elements with class "depth_item"
for li_element in li_elements_with_class:
    print(li_element)
# Out:
# <li class="depth_item"> <a class="depth_link" href="https://product.kyobobook.co.kr/bestseller/total" onclick="ga360.GA_Event('click_공통_PC', 'LNB', '서비스전체보기', '주요서비스&gt;종합 베스트셀러', '');">종합 베스트셀러</a> </li>
# <li class="depth_item"> <a class="depth_link" href="https://product.kyobobook.co.kr/bestseller/steady" onclick="ga360.GA_Event('click_공통_PC', 'LNB', '서비스전체보기', '주요서비스&gt;스테디셀러', '');">스테디셀러</a> </li>
# <li class="depth_item"> <a class="depth_link" href="https://product.kyobobook.co.kr/new/" onclick="ga360.GA_Event('click_공통_PC', 'LNB', '서비스전체보기', '주요서비스&gt;신상품', '');">신상품</a> </li>
# <li class="depth_item"> <a class="depth_link" href="https://www.kyobobook.co.kr/service/gift-promotion/main" onclick="ga360.GA_Event('click_공통_PC', 'LNB', '서비스전체보기', '주요서비스&gt;사은품', '');">사은품</a> </li>
# <li class="depth_item"> <a class="depth_link" href="https://www.kyobobook.co.kr/service/special-price" onclick="ga360.GA_Event('click_공통_PC', 'LNB', '서비스전체보기', '주요서비스&gt;특가', '');">특가</a> </li>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://product.kyobobook.co.kr/bestseller/online?period=001#?page=1&per=20&ymw=&period=001&saleCmdtClstCode=&dsplDvsnCode=000&dsplTrgtDvsnCode=001&saleCmdtDsplDvsnCode="
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"
}

html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')

# Find all <li> elements with class "prod_item"
li = soup.find('li', {'class':'prod_item'})

boxes = li.find("span", {"class": "prod_name"})

for box in boxes:
    print(box)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\gusdk\OneDrive\바탕 화면\금오공대 1-2\ai프로그래밍\ai-programming\웹크롤링\교보문고.ipynb 셀 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/gusdk/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EA%B8%88%EC%98%A4%EA%B3%B5%EB%8C%80%201-2/ai%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/ai-programming/%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81/%EA%B5%90%EB%B3%B4%EB%AC%B8%EA%B3%A0.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> # Find all <li> elements with class "prod_item"
#      <a href='vscode-notebook-cell:/c%3A/Users/gusdk/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EA%B8%88%EC%98%A4%EA%B3%B5%EB%8C%80%201-2/ai%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/ai-programming/%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81/%EA%B5%90%EB%B3%B4%EB%AC%B8%EA%B3%A0.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a> li = soup.find('li', {'class':'prod_item'})
# ...

# %%
! pip install bs4
